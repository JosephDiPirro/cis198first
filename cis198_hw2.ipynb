# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephDiPirro/cis198first/blob/main/cis198_hw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a function in python always has a list of parenthesis following the function name. In the parenthesis put your function inputs aka ***parameters***.

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## Creating a poem with chatgpt
#
# ***Here is our prompt:***
#
# Create rhyming song lyrics about a niagara university class called intro to computer education with students, Sophie, Andrew, Julian, Joe, Cue, and professor Ty. they study structured programming, office applications, creating websites. admin perspective of educational platforms, google slides, but they don't cover IPHONE. mention the school mascot and other things about Niagara University
#
#
#
# ---
#
# ***Here's the output:***
#
# **Verse 1**
# Up on Monteagle Ridge where the purple flags fly,
# Niagara University reaching for the sky.
# In Intro to Computer Ed, the classroom’s alive,
# Sophie, Andrew, Julian, Joe, Cue ready to dive.
#
# **Pre-Chorus**
# Professor Ty at the helm, got the lesson on track,
# From code to clicks to campus life, there’s no holding back.
#
# **Chorus**
# We’re learning structured programming, line by line,
# Office apps and websites, yeah we’re doing fine.
# Admin view of platforms, running smooth and clean,
# Google Slides on the screen, keeping lessons keen.
# Purple Eagles soaring high, school spirit in the air—
# But iPhone talk? Nah, that’s not covered here!
#
# **Verse 2**
# From St. Vincent’s dome to the Quad’s bright green,
# Building digital futures in a purple-and-white dream.
# Typing up the logic, making websites shine,
# Campus tech and classroom checks, everything aligns.
#
# **Bridge**
# Dashboards and data, learning how to manage,
# Education platforms lined up in advantage.
# Ty says, “Keep it focused, stay within the plan,”
# No iPhone shortcuts—learn it like an admin can.
#
# **Final Chorus / Outro**
# Structured code and slides that glow,
# Purple Eagles proud and ready to go.
# Niagara nights and lessons tight,
# We code, create, and learn it right—
# In Computer Ed we rise and share,
# Monteagle Ridge in the purple air!
#
# ---
#
# If you want it **more serious, more funny, or styled like a specific genre** (pop, rap, country, school anthem vibe), I can remix it 👍

# %% [markdown]
# ### Markdown Basics
# ---
# ***End a line with two spaces to create a new line***
#
# **Bold**
#
# *Italic*
#
#
# Bulleted List:
# * I
# * Like
# * Computers
#
#
# Numbered List
# 1. welcome
# 1. to
# 1. Niagara
# 1. University

# %% [markdown]
# | Name | Major |
# |:----------|----------:|
# | Monte  | Computer Science  |
# | Father Maher  | Theology  |

# %% [markdown]
# #### Links
# [Niagara University](https://niagara.edu)
