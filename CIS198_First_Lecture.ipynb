# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephDiPirro/cis198first/blob/main/CIS198_First_Lecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Colab Notes
#
# * Colab uses interactive pyhton notebooks (.ipynb files).
# * A notebook is made up of a verticle stack of cells.
# * There are two cell types:
#   1. Code - Python
#   1. Text - Raw text, markdown or html
#
# *markdown* - is a simple "markup language" that allows you to
#
# ### Examples of markdown
#
# **bold text**
#
# *italic text*
#
# [The best university on earth](http://niagara.edu)

# %%
1. # This is a python comment
2. # code comments get ignored when the program is run
3. print('Hello World')
# Out:
# Hello World
